# %%
#start 5 objectSwarmModelBugs.py
from Tools import *
from ModelSwarm import *

nBugs = input("How many bugs? ")
worldXSize= input("X Size of the world? ")
worldYSize= input("Y Size of the world? ")
nCycles = input("How many cycles? (0 = exit) ")

modelSwarm = ModelSwarm(nBugs, nCycles, worldXSize, worldYSize)

# create objects
modelSwarm.buildObjects()

# create actions
modelSwarm.buildActions()

# run
modelSwarm.run()

print
print "Simulation stopped after ", nCycles, " cycles"
# Out:
# How many bugs? 10
# X Size of the world? 100
# Y Size of the world? 100
# How many cycles? (0 = exit) 5
# Bug number  0  has been created at  70 ,  46
# Bug number  1  has been created at  24 ,  27
# Bug number  2  has been created at  39 ,  99
# Bug number  3  has been created at  75 ,  7
# Bug number  4  has been created at  69 ,  38
# Bug number  5  has been created at  98 ,  67
# Bug number  6  has been created at  61 ,  86
# Bug number  7  has been created at  78 ,  74
# Bug number  8  has been created at  60 ,  43
# Bug number  9  has been created at  3 ,  54
#
# bug #  4 moving
# jumping
# bug #  0 moving
# jumping
# bug #  6 moving
# bug #  5 moving
# jumping
# bug #  8 moving
# jumping
# bug #  7 moving
# jumping
# bug #  1 moving
# bug #  3 moving
# bug #  2 moving
# jumping
# bug #  9 moving
# Time =  0 ask all agents to report position
# Bug number  0  moved to X =  67.3796801824  Y =  48.6203198176
# Bug number  1  moved to X =  23  Y =  26
# Bug number  2  moved to X =  34.7432251611  Y =  94.7432251611
# Bug number  3  moved to X =  76  Y =  8
# Bug number  4  moved to X =  73.5479103549  Y =  33.4520896451
# Bug number  5  moved to X =  0.2919521233  Y =  67.0
# Bug number  6  moved to X =  60  Y =  85
# Bug number  7  moved to X =  82.8736105321  Y =  69.1263894679
# Bug number  8  moved to X =  64.8838006314  Y =  47.8838006314
# Bug number  9  moved to X =  4  Y =  53
# bug #  2 moving
# jumping
# bug #  3 moving
# bug #  4 moving
# jumping
# bug #  7 moving
# jumping
# bug #  8 moving
# jumping
# bug #  5 moving
# jumping
# bug #  1 moving
# jumping
# bug #  0 moving
# jumping
# bug #  6 moving
# bug #  9 moving
# jumping
# Time =  1 ask first agent to report position
# Bug number  0  moved to X =  67.3796801824  Y =  45.7368221455
# bug #  1 moving
# bug #  9 moving
# bug #  0 moving
# bug #  8 moving
# jumping
# bug #  3 moving
# jumping
# bug #  5 moving
# bug #  2 moving
# jumping
# bug #  4 moving
# jumping
# bug #  6 moving
# jumping
# bug #  7 moving
# jumping
# Time =  2 ask first agent to report position
# Bug number  0  moved to X =  67.3796801824  Y =  45.7368221455
# bug #  1 moving
# jumping
# bug #  2 moving
# jumping
# bug #  4 moving
# jumping
# bug #  8 moving
# jumping
# bug #  0 moving
# jumping
# bug #  9 moving
# bug #  5 moving
# jumping
# bug #  6 moving
# bug #  3 moving
# jumping
# bug #  7 moving
# Time =  3 ask all agents to report position
# Bug number  0  moved to X =  70.6994619136  Y =  45.7368221455
# Bug number  1  moved to X =  25.4188326097  Y =  26.6168319407
# Bug number  2  moved to X =  28.1440000161  Y =  3.44606795381
# Bug number  3  moved to X =  67.7734830801  Y =  16.2265169199
# Bug number  4  moved to X =  71.2780772021  Y =  31.4741019219
# Bug number  5  moved to X =  1.2919521233  Y =  70.6015000661
# Bug number  6  moved to X =  63.7234907789  Y =  82.2765092211
# Bug number  7  moved to X =  85.7981809929  Y =  68.1263894679
# Bug number  8  moved to X =  62.0266543648  Y =  48.5355445509
# Bug number  9  moved to X =  0.422706362199  Y =  49.4227063622
# bug #  3 moving
# jumping
# bug #  5 moving
# jumping
# bug #  4 moving
# bug #  2 moving
# jumping
# bug #  9 moving
# jumping
# bug #  1 moving
# bug #  8 moving
# jumping
# bug #  6 moving
# bug #  0 moving
# jumping
# bug #  7 moving
# Time =  4 ask first agent to report position
# Bug number  0  moved to X =  70.6994619136  Y =  45.7368221455
#
# Simulation stopped after  5  cycles
